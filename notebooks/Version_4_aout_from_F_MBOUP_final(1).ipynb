# %% [markdown]
# # Pour les modèles

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/MLOPS_Project
# Out:
# /content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/MLOPS_Project

# %%
pwd
# Out:
# '/content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/MLOPS_Project'

# %%
device='cuda'

# %%
#For colab
# !pip install pyngrok

# %%
#For Colab
# !pip install pendulum
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 12.0 MB/s eta 0:00:00
# ...

# %%
#For Colab
# !pip install ydata_profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.2/356.2 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 25.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 45.5 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=8362af70e8f3e69891b6b334122379954ed4095ba3c55a67373042447e1970b4
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
# !pip install mlflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.3/26.3 MB 31.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 71.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.6/505.6 kB 36.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.9/202.9 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 10.0 MB/s eta 0:00:00
# ...

# %%
#For Colab
# !pip install loguru
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Importation des Modules

# %%
# %reload_ext autoreload
# %autoreload 2


from tensorflow.keras.optimizers import Adam
import cv2
import matplotlib.pyplot as plt
import mlflow
from mlflow import log_artifacts, log_metric, log_param
from mlflow.tracking import MlflowClient
from pathlib import Path
import pandas as pd
from pyngrok import ngrok
from sklearn.metrics import accuracy_score, log_loss, precision_score, recall_score, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize, LabelEncoder, LabelBinarizer
import numpy as np
import os
import random
from settings.config import *
from src.make_dataset import *
from src.make_model import *
import sys
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2,VGG16
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
from tensorflow.keras.models import Model, save_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from torchvision import models
from tqdm import tqdm
from ydata_profiling import ProfileReport
from loguru import logger
from collections import Counter
import pendulum

# %% [markdown]
# # Fonction évaluant les métriques du modèle

# %%
def eval_metrics(y_true, y_pred, y_pred_proba):
    """
    Calcule les métriques pour une classification multiclasse.

    param y_true: Les vraies étiquettes
    param y_pred: Les prédictions du modèle
    param y_pred_proba: Les probabilités prédites par le modèle
    return: Un dictionnaire contenant les métriques calculées
    """
    # Accuracy
    accuracy = accuracy_score(y_true, y_pred)

    # Precision, Recall
    # y_true et y_pred sont les labels réels et prédits respectivement
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')

    # Log Loss
    logloss = log_loss(y_true, y_pred_proba)

    # ROC AUC (one-vs-rest)
    n_classes = y_pred_proba.shape[1]
    y_true_bin = label_binarize(y_true, classes=range(n_classes))
    roc_auc = {}
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred_proba[:, i])
        roc_auc[i] = auc(fpr, tpr)

    # Moyenne des ROC AUC
    mean_roc_auc = np.mean(list(roc_auc.values()))

    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'log_loss': logloss,
        'roc_auc': roc_auc,
        'mean_roc_auc': mean_roc_auc
    }

# %% [markdown]
# # Functions For MobileNetV2 Model

# %%
def create_and_get_model(input_shape=(128, 128, 3), num_classes=6, learning_rate=0.0001):
    base_model = MobileNetV2(input_shape=input_shape, include_top=False, weights='imagenet')
    base_model.trainable = False

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(512, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])

    model.compile(optimizer=Adam(learning_rate=learning_rate),
                  loss=SparseCategoricalCrossentropy(),
                  metrics=[SparseCategoricalAccuracy()])

    params = {
        'input_shape': input_shape,
        'num_classes': num_classes,
        'learning_rate': learning_rate,
        'optimizer': 'Adam',
        'loss': 'SparseCategoricalCrossentropy',
        'metrics': 'SparseCategoricalAccuracy'
    }

    return model, params

# %%
# Exemple d'utilisation
#model, params = create_and_get_model(input_shape=MOBILENETV2_CONFIG["input_shape"], num_classes=MOBILENETV2_CONFIG["num_classes"], learning_rate=MOBILENETV2_CONFIG["learning_rate"])

# Afficher les paramètres du modèle
#print("Modèle créé avec les paramètres suivants:")
#for key, value in params.items():
    #print(f"{key}: {value}")

# %%
# Assurez-vous que les étiquettes sont sous forme entière
def prepare_labels(labels):
    if len(labels.shape) > 1 and labels.shape[-1] > 1:
        # Convertir les étiquettes one-hot en entiers
        return np.argmax(labels, axis=-1)
    return labels

# %%
def train_model(model, x_train, y_train, x_val, y_val,y_test,epochs, patience=5):
    # Préparer les étiquettes
    y_train = prepare_labels(y_train)
    y_val = prepare_labels(y_val)
    y_test = prepare_labels(y_test)
    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)

    history = model.fit(x_train, y_train,
                        epochs=epochs,
                        validation_data=(x_val, y_val),
                        callbacks=[early_stopping])

    return history

# %%
# Exemple d'utilisation
#history = train_model(model, x_train, y_train, x_val, y_val, epochs=50, patience=5)

# %%
def test_model_on_all(model, X_test, y_test):
    """
    Teste le modèle sur toutes les images de l'ensemble de test.

    Arguments:
    model -- Le modèle entraîné.
    X_test -- Données de test.
    y_test -- Étiquettes de test.

    Retourne:
    results -- Une liste de tuples contenant la classe prédite et la classe réelle pour chaque image.
    y_pred_proba -- Probabilités prédites pour chaque classe.
    """
    y_test = prepare_labels(y_test)
    results = []
    y_pred_proba = []

    for index_test in range(len(X_test)):
        # Sélectionne l'image à prédire
        image_to_predict = np.expand_dims(X_test[index_test], axis=0)

        # Effectue la prédiction
        predictions = model.predict(image_to_predict)
        predicted_class_index = np.argmax(predictions[0])
        real_class_index = y_test[index_test]

        # Stocker les probabilités prédites
        y_pred_proba.append(predictions[0])

        # Obtenez les noms des classes prédite et réelle
        predicted_class = class_names[predicted_class_index]
        real_class = class_names[real_class_index]

        # Stocke les résultats
        results.append((predicted_class, real_class))

    return results, np.array(y_pred_proba)

# %%
# Testez le modèle sur toutes les données de test
#results, y_pred_proba = test_model_on_all(model, x_test, y_test)

# %%
# Extraire les classes prédites et réelles
#y_pred = [class_names.index(pred) for pred, _ in results]
#y_true = [class_names.index(real) for _, real in results]

#print("y_pred_proba:", len(y_pred_proba))


#print("y_true:", len(y_true))
#print("y_pred:", len(y_pred))

# Afficher les métriques
#print(f"Accuracy: {metrics['accuracy']}")
#print(f"Precision: {metrics['precision']}")
#print(f"Recall: {metrics['recall']}")
#print(f"Log Loss: {metrics['log_loss']}")
#print(f"Mean ROC AUC: {metrics['mean_roc_auc']}")

# %% [markdown]
# # ✨MLFLOW TRACKING✨

# %% [markdown]
# ### 🧨Configurations dans un environnement colab

# %% [markdown]
# ## Single Model = MobileNetv2

# %%
# Set the tracking server to be localhost with sqlite as tracking store
local_registry = "sqlite:///mlruns.db"
print(f"Running local model registry={local_registry}")
model_name="MobileNetV2Model"
mlflow.set_tracking_uri(local_registry)
# Out:
# Running local model registry=sqlite:///mlruns.db

# %%
# Create an experiment if not exists
exp_name = "garbage_classification"
experiment = mlflow.get_experiment_by_name(exp_name)
if not experiment:
    experiment_id = mlflow.create_experiment(exp_name)
else:
    experiment_id = experiment.experiment_id

logger.info(f"Experience id: {experiment_id}")
# Out:
# 2024-08-05 11:43:35.793 | INFO     | __main__:<cell line: 9>:9 - Experience id: 1

# %%
import mlflow
import mlflow.keras
from datetime import datetime
import numpy as np
from mlflow.models import infer_signature

# Assure-toi que ton environnement MLflow est configuré
# mlflow.set_tracking_uri("file:///path_to_your_mlflow_tracking_directory")
# mlflow.set_experiment("Garbage_Classification")

# Créer et configurer le modèle
def run_experiment(experiment_id):

    with mlflow.start_run(run_name=f"garbage_classification_{datetime.now().strftime('%Y%m%d_%H%M%S')}",
                         experiment_id=experiment_id,
                          tags={"version": "v1", "priority": "P1"},
                          description="garbage classification modeling",) as run:
        # Enregistre le paramètre du modèle (si applicable)
        mlflow.log_param("model", "MobileNetV2")
        mlflow.log_param("input_shape", (128, 128, 3))

        # Créer le modèle
        model, params = create_and_get_model()
        mlflow.log_params(params)

        # Entraîner le modèle
        history = train_model(model, x_train, y_train, x_val, y_val,y_test,epochs=params["epochs"])

        # Enregistre les métriques d'entraînement
        for epoch in range(len(history.history['loss'])):
            mlflow.log_metric(f"train_loss", history.history['loss'][epoch], step=epoch)
            mlflow.log_metric(f"sparse_categorical_accuracy", history.history['sparse_categorical_accuracy'][epoch], step=epoch)
            if 'val_loss' in history.history:
                mlflow.log_metric(f"val_loss", history.history['val_loss'][epoch], step=epoch)
            if 'val_accuracy' in history.history:
                mlflow.log_metric(f"val_sparse_categorical_accuracy", history.history['val_sparse_categorical_accuracy'][epoch], step=epoch)

        # Tester le modèle
        results, y_pred_proba = test_model_on_all(model, x_test, y_test)


        # Extraire les classes prédites et réelles
        y_pred = [class_names.index(pred) for pred, _ in results]
        y_true = [class_names.index(real) for _, real in results]

        # Évaluer les métriques du modèle
        metrics = eval_metrics(y_true, y_pred, y_pred_proba)

        # Log des métriques
        mlflow.log_metric("test_accuracy", metrics['accuracy'])
        mlflow.log_metric("test_precision", metrics['precision'])
        mlflow.log_metric("test_recall", metrics['recall'])
        mlflow.log_metric("test_log_loss", metrics['log_loss'])
        mlflow.log_metric("test_mean_roc_auc", metrics['mean_roc_auc'])

        # Log des ROC AUC pour chaque classe
        for class_index, class_roc_auc in metrics['roc_auc'].items():
            mlflow.log_metric(f"test_roc_auc_class_{class_index}", class_roc_auc)

        # Enregistrer le modèle avec la signature
        signature = infer_signature(x_test, y_pred_proba)
        mlflow.keras.log_model(model, artifact_path="model", signature=signature, registered_model_name="MobileNetV2Model")

        if not os.path.exists("outputs"):
            os.makedirs("outputs")
        with open("outputs/test.txt", "w") as f:
            f.write("Looks, like I logged to the local store!")
        log_artifacts("outputs")
        shutil.rmtree('outputs')

        print(f"Model run logged to MLflow with run_id: {run.info.run_id}")

# %%
# Exécuter l'expérience
run_experiment(experiment_id)
# Out:
# Epoch 1/5
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - loss: 1.5850 - sparse_categorical_accuracy: 0.3460 - val_loss: 1.2851 - val_sparse_categorical_accuracy: 0.4729
# Epoch 2/5
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - loss: 1.1529 - sparse_categorical_accuracy: 0.5233 - val_loss: 1.2360 - val_sparse_categorical_accuracy: 0.4806
# Epoch 3/5
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.0372 - sparse_categorical_accuracy: 0.5727 - val_loss: 1.1859 - val_sparse_categorical_accuracy: 0.5039
# Epoch 4/5
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.9976 - sparse_categorical_accuracy: 0.5934 - val_loss: 1.1647 - val_sparse_categorical_accuracy: 0.5240
# Epoch 5/5
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.9807 - sparse_categorical_accuracy: 0.5888 - val_loss: 1.1750 - val_sparse_categorical_accuracy: 0.4791
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# ...

# %%
#import mlflow
#runs = mlflow.search_runs(experiment_ids=[experiment_id])
#print(runs)

# %%
#client = MlflowClient()
# Obtenir une liste de versions spécifiques des modèles nommés
#print(f"List of Model = {model_name} and Versions")
#print("=" * 80)
#[pprint.pprint(dict(mv), indent=4) for mv in client.search_model_versions(f"name='{model_name}'")]
# Out:
# List of Model = MobileNetV2Model and Versions
# ...
# {   'aliases': [],
#     'creation_timestamp': 1722861355931,
#     'current_stage': 'None',
#     'description': None,
#     'last_updated_timestamp': 1722861355931,
#     'name': 'MobileNetV2Model',
#     'run_id': 'b44d930517664c69be01a6e14d5a6752',
#     'run_link': None,
#     'source': '/content/drive/MyDrive/MLFlow_Class_Project/MLOPS_Project/mlruns/1/b44d930517664c69be01a6e14d5a6752/artifacts/model',
#     'status': 'READY',
#     'status_message': None,
#     'tags': {},
#     'user_id': None,
#     'version': 2}
# {   'aliases': [],
#     'creation_timestamp': 1722861068238,
#     'current_stage': 'None',
#     'description': None,
#     'last_updated_timestamp': 1722861068238,
#     'name': 'MobileNetV2Model',
#     'run_id': 'd6f8e363180a4157817ba0ac40ecfd75',
#     'run_link': None,
#     'source': '/content/drive/MyDrive/MLFlow_Class_Project/MLOPS_Project/mlruns/1/d6f8e363180a4157817ba0ac40ecfd75/artifacts/model',
# ...

# %%
# run tracking UI in the background
get_ipython().system_raw("mlflow ui --backend-store-uri sqlite:///mlruns.db --port 5000 &")# run tracking UI in the background

# %%
from pyngrok import ngrok

# Terminate open tunnels if they exist
ngrok.kill()

# Setting the authtoken (optional)
NGROK_AUTH_TOKEN = "2kD0rcbkl66GfLcWrG5GeU0GZ1w_7x9onfXmmEUvwCS3pBWs6"  # Replace with your actual ngrok auth token
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Open an HTTPs tunnel on port 5000 for http://localhost:5000
public_url = ngrok.connect(5000, bind_tls=True)
print("MLflow Tracking UI:", public_url)
# Out:
# MLflow Tracking UI: NgrokTunnel: "https://6668-35-197-132-192.ngrok-free.app" -> "http://localhost:5000"

# %% [markdown]
# ## Multiple models : VGG16, MobileNetV2 & DenseNet

# %% [markdown]
# ## Config for VGG16

# %%
def create_data_loaders_for_VGG16(x_train, x_val, x_test, y_train, y_val, y_test, config):
    """
    Convertit les données et les étiquettes en tensors PyTorch et crée des DataLoaders pour l'entraînement,
    la validation et le test.

    Arguments:
    x_train, x_val, x_test -- Les données d'entraînement, de validation et de test (numpy arrays).
    y_train, y_val, y_test -- Les étiquettes d'entraînement, de validation et de test (numpy arrays one-hot).
    batch_size -- Taille des batches pour les DataLoaders.

    Retourne:
    train_loader, val_loader, test_loader -- Les DataLoaders pour l'entraînement, la validation et le test.
    """

    # Conversion des labels one-hot en indices de classe
    y_train_indices = np.argmax(y_train, axis=1)
    y_val_indices = np.argmax(y_val, axis=1)
    y_test_indices = np.argmax(y_test, axis=1)

    # Conversion en tensors PyTorch
    y_train_tensor = torch.tensor(y_train_indices, dtype=torch.long)
    y_val_tensor = torch.tensor(y_val_indices, dtype=torch.long)
    y_test_tensor = torch.tensor(y_test_indices, dtype=torch.long)

    # Conversion des tableaux numpy en tensors PyTorch et permutation des dimensions
    x_train_tensor = torch.tensor(x_train, dtype=torch.float32).permute(0, 3, 1, 2)
    x_val_tensor = torch.tensor(x_val, dtype=torch.float32).permute(0, 3, 1, 2)
    x_test_tensor = torch.tensor(x_test, dtype=torch.float32).permute(0, 3, 1, 2)

    # Création des jeux de données PyTorch
    train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
    val_dataset = TensorDataset(x_val_tensor, y_val_tensor)
    test_dataset = TensorDataset(x_test_tensor, y_test_tensor)

    # Création des DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config['batch_size'], shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=config['batch_size'], shuffle=False)

    # Vérification des tailles des DataLoaders
    print(f"Nombre de batches dans le DataLoader d'entraînement : {len(train_loader)}")
    print(f"Nombre de batches dans le DataLoader de validation : {len(val_loader)}")
    print(f"Nombre de batches dans le DataLoader de test : {len(test_loader)}")

    return train_loader, val_loader, test_loader


def create_vgg16_model(config):
    model = models.vgg16(pretrained=config['pretrained'])
    model.classifier[6] = nn.Linear(model.classifier[6].in_features, config['num_classes'])
    return model

def train_vgg16_model(model, train_loader, val_loader, config):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'])

    for epoch in range(config['epochs']):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_accuracy = 100 * correct / total

        # Calculate metrics on validation set
        model.eval()
        val_labels = []
        val_preds = []
        val_preds_proba = []

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                val_labels.extend(labels.cpu().numpy())
                val_preds.extend(torch.max(outputs, 1)[1].cpu().numpy())
                val_preds_proba.extend(torch.softmax(outputs, dim=1).cpu().numpy())

        # Convert lists to numpy arrays
        val_labels = np.array(val_labels)
        val_preds = np.array(val_preds)
        val_preds_proba = np.array(val_preds_proba)

        # Evaluate metrics
        metrics = eval_metrics(val_labels, val_preds, val_preds_proba)

        # Print metrics
        print(f"Epoch {epoch+1}/{config['epochs']} - Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%")
        print(f"Validation Metrics - Accuracy: {metrics['accuracy']:.4f}, Precision: {metrics['precision']:.4f}, Recall: {metrics['recall']:.4f}, Log Loss: {metrics['log_loss']:.4f}, Mean ROC AUC: {metrics['mean_roc_auc']:.4f}")

    return model




def test_model_VGG16(model, test_loader):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    model.eval()  # Passer le modèle en mode évaluation

    all_labels = []
    all_preds = []
    all_preds_proba = []

    with torch.no_grad():  # Pas besoin de calculer les gradients
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)

            # Prédictions et probabilités
            _, preds = torch.max(outputs, 1)
            preds_proba = torch.softmax(outputs, dim=1)  # Probabilités prédites

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())
            all_preds_proba.extend(preds_proba.cpu().numpy())

    # Convertir les listes en tableaux numpy
    y_true = np.array(all_labels)
    y_pred = np.array(all_preds)
    y_pred_proba = np.array(all_preds_proba)

    # Calculer les métriques
    metrics = eval_metrics(y_true, y_pred, y_pred_proba)

    return metrics

# %% [markdown]
# ### Test des fonctions de VGG19

# %%
# VGG16 example
#vgg16_model = create_vgg19_model(VGG19_CONFIG)

# %%
# Supposons que vous ayez déjà divisé vos données en x_train, x_val, x_test, y_train, y_val, y_test
#train_loader, val_loader, test_loader = create_data_loaders_for_VGG16(x_train, x_val, x_test, y_train, y_val, y_test,VGG19_CONFIG)
#trained_vgg16 = train_vgg16_model(vgg19_model, train_loader, val_loader, VGG19_CONFIG)

# %%
# Utilisation de la fonction
#metrics = test_model_VGG16(trained_vgg16, test_loader)
#print("Metrics on the test set:")
#print(metrics)

# %% [markdown]
# ### Définition des params des modèles (Executer les cellules en bas d'abord)

# %%
from settings.config import *

# %%
pwd
# Out:
# '/content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/MLOPS_Project'

# %%
# Define models and parameters to benchmark
ESTIMATOR_PARAMS = {MobileNetV2.__name__: {"estimator": MobileNetV2,
                                                     "params": MOBILENETV2_CONFIG
                                             },
                    VGG16.__name__: {"estimator": VGG16,
                                                     "params": VGG16_CONFIG
                                             }
}

ESTIMATOR_PARAMS
# Out:
# {'MobileNetV2': {'estimator': <function keras.src.applications.mobilenet_v2.MobileNetV2(input_shape=None, alpha=1.0, include_top=True, weights='imagenet', input_tensor=None, pooling=None, classes=1000, classifier_activation='softmax', name=None)>,
#   'params': {'input_shape': (128, 128, 3),
#    'num_classes': 6,
#    'learning_rate': 0.0001,
#    'epochs': 50,
#    'patience': 5,
#    'pretrained': True,
#    'model_path': 'mobilenetv2_pretrained.pth'}},
#  'VGG16': {'estimator': <function keras.src.applications.vgg16.VGG16(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', name='vgg16')>,
#   'params': {'input_shape': (128, 128, 3),
#    'num_classes': 6,
#    'learning_rate': 1e-05,
#    'batch_size': 32,
#    'epochs': 30,
#    'pretrained': True,
#    'model_path': 'vgg19_pretrained.pth'}}}

# %%
for model_name, model_configs in ESTIMATOR_PARAMS.items():
    estimator = model_configs["estimator"]
    params = model_configs["params"]

    print(f"Model Name: {model_name}")
    print(f"Estimator: {estimator}")
    print(f"Params: {params}")
    print("=" * 40)
# Out:
# Model Name: MobileNetV2
# Estimator: <function MobileNetV2 at 0x7abe687d9fc0>
# Params: {'input_shape': (128, 128, 3), 'num_classes': 6, 'learning_rate': 0.0001, 'epochs': 50, 'patience': 5, 'pretrained': True, 'model_path': 'mobilenetv2_pretrained.pth'}
# ...
# Model Name: VGG16
# Estimator: <function VGG16 at 0x7abe6860c430>
# Params: {'input_shape': (128, 128, 3), 'num_classes': 6, 'learning_rate': 1e-05, 'batch_size': 32, 'epochs': 30, 'pretrained': True, 'model_path': 'vgg19_pretrained.pth'}
# ...

# %% [markdown]
# # Config for MLFlow

# %%
# Set the tracking server to be localhost with sqlite as tracking store
local_registry = "sqlite:///mlruns.db"
print(f"Running local model registry={local_registry}")
mlflow.set_tracking_uri(local_registry)
# Out:
# Running local model registry=sqlite:///mlruns.db

# %% [markdown]
# # Create an experiment

# %%
# Create an experiment if not exists
exp_name = "garbage_classification"
experiment = mlflow.get_experiment_by_name(exp_name)
if not experiment:
    experiment_id = mlflow.create_experiment(exp_name)
else:
    experiment_id = experiment.experiment_id

logger.info(f"Experience id: {experiment_id}")
# Out:
# 2024-08-05 15:51:43.949 | INFO     | __main__:<cell line: 9>:9 - Experience id: 1

# %%
import mlflow
import mlflow.keras
from datetime import datetime
import numpy as np
from mlflow.models import infer_signature

# Assure-toi que ton environnement MLflow est configuré
# mlflow.set_tracking_uri("file:///path_to_your_mlflow_tracking_directory")
# mlflow.set_experiment("Garbage_Classification")

# Créer et configurer le modèle
def run_experiment(experiment_id):

    for model_name, model_configs in ESTIMATOR_PARAMS.items():
        logger.info(f"{model_name} \n{model_configs}")

        #estimator = model_configs["estimator"]
        params = model_configs["params"]
        print("params['epochs'] : ",params['epochs'])
        with mlflow.start_run(run_name=f"garbage_classification_{datetime.now().strftime('%Y%m%d_%H%M%S')}",
                             experiment_id=experiment_id,
                              tags={"version": "v1", "priority": "P1"},
                              description="garbage classification modeling",) as run:
            # Enregistre le paramètre du modèle (si applicable)
            mlflow.log_param("model", model_name)
            mlflow.log_param("input_shape", params["input_shape"])
            epoch_number=params["epochs"]

            # Pour MobileNetV2
            if model_name == "MobileNetV2":

                # Créer le modèle
                model, params = create_and_get_model()
                mlflow.log_params(params)

                # Entraîner le modèle
                history = train_model(model, x_train, y_train, x_val, y_val ,y_test, epochs=epoch_number)

                # Enregistre les métriques d'entraînement
                for epoch in range(len(history.history['loss'])):
                    mlflow.log_metric(f"train_loss", history.history['loss'][epoch], step=epoch)
                    mlflow.log_metric(f"sparse_categorical_accuracy", history.history['sparse_categorical_accuracy'][epoch], step=epoch)
                    if 'val_loss' in history.history:
                        mlflow.log_metric(f"val_loss", history.history['val_loss'][epoch], step=epoch)
                    if 'val_accuracy' in history.history:
                        mlflow.log_metric(f"val_sparse_categorical_accuracy", history.history['val_sparse_categorical_accuracy'][epoch], step=epoch)

                # Tester le modèle
                results, y_pred_proba = test_model_on_all(model, x_test, y_test)


                # Extraire les classes prédites et réelles
                y_pred = [class_names.index(pred) for pred, _ in results]
                y_true = [class_names.index(real) for _, real in results]

                # Évaluer les métriques du modèle
                metrics = eval_metrics(y_true, y_pred, y_pred_proba)

            elif model_name == "VGG16":
                # VGG16 example
                vgg16_model = create_vgg16_model(VGG16_CONFIG)

                train_loader, val_loader, test_loader = create_data_loaders_for_VGG16(x_train, x_val, x_test, y_train, y_val, y_test,VGG16_CONFIG)
                trained_vgg16 = train_vgg16_model(vgg16_model, train_loader, val_loader, VGG16_CONFIG)

                # Utilisation de la fonction
                metrics = test_model_VGG16(trained_vgg16, test_loader)
                #print("Metrics on the test set:")
                #print(metrics)


            # Log des métriques
            mlflow.log_metric("test_accuracy", metrics['accuracy'])
            mlflow.log_metric("test_precision", metrics['precision'])
            mlflow.log_metric("test_recall", metrics['recall'])
            mlflow.log_metric("test_log_loss", metrics['log_loss'])
            mlflow.log_metric("test_mean_roc_auc", metrics['mean_roc_auc'])

            # Log des ROC AUC pour chaque classe
            for class_index, class_roc_auc in metrics['roc_auc'].items():
                mlflow.log_metric(f"test_roc_auc_class_{class_index}", class_roc_auc)

            # Enregistrer le modèle avec la signature
            signature = infer_signature(x_test, y_pred_proba)
            #mlflow.keras.log_model(model, artifact_path="model", signature=signature)
            mlflow.keras.log_model(model, artifact_path="model", signature=signature, registered_model_name=model_name)

            if not os.path.exists("outputs"):
                os.makedirs("outputs")
            with open("outputs/test.txt", "w") as f:
                f.write("Looks, like I logged to the local store!")
            log_artifacts("outputs")
            shutil.rmtree('outputs')

            print(f"Model run logged to MLflow with run_id: {run.info.run_id}")

# %%
# Exécuter l'expérience pour plusieurs modeles
run_experiment(experiment_id)
# Out:
# 2024-08-05 16:31:07.021 | INFO     | __main__:run_experiment:15 - MobileNetV2
# {'estimator': <function MobileNetV2 at 0x7abe687d9fc0>, 'params': {'input_shape': (128, 128, 3), 'num_classes': 6, 'learning_rate': 0.0001, 'epochs': 50, 'patience': 5, 'pretrained': True, 'model_path': 'mobilenetv2_pretrained.pth'}}
# params['epochs'] :  50
# Epoch 1/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - loss: 1.5820 - sparse_categorical_accuracy: 0.3525 - val_loss: 1.3039 - val_sparse_categorical_accuracy: 0.4636
# Epoch 2/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 1.1728 - sparse_categorical_accuracy: 0.5332 - val_loss: 1.2242 - val_sparse_categorical_accuracy: 0.4899
# Epoch 3/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.0746 - sparse_categorical_accuracy: 0.5678 - val_loss: 1.2034 - val_sparse_categorical_accuracy: 0.4977
# Epoch 4/50
# ...

# %% [markdown]
# # Access to the MLFLOW UI

# %%
# run tracking UI in the background
get_ipython().system_raw("mlflow ui --backend-store-uri sqlite:///mlruns.db --port 5000 &")# run tracking UI in the background

# %%
from pyngrok import ngrok

# Terminate open tunnels if they exist
ngrok.kill()

# Setting the authtoken (optional)
NGROK_AUTH_TOKEN = "2kD0rcbkl66GfLcWrG5GeU0GZ1w_7x9onfXmmEUvwCS3pBWs6"  # Replace with your actual ngrok auth token
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Open an HTTPs tunnel on port 5000 for http://localhost:5000
public_url = ngrok.connect(5000, bind_tls=True)
print("MLflow Tracking UI:", public_url)
# Out:
# MLflow Tracking UI: NgrokTunnel: "https://767d-34-125-130-20.ngrok-free.app" -> "http://localhost:5000"

# %%
#!mlflow ui
# Out:
# [2024-08-05 00:42:00 +0000] [63054] [INFO] Starting gunicorn 22.0.0
# [2024-08-05 00:42:00 +0000] [63054] [INFO] Listening at: http://127.0.0.1:5000 (63054)
# [2024-08-05 00:42:00 +0000] [63054] [INFO] Using worker: sync
# [2024-08-05 00:42:00 +0000] [63057] [INFO] Booting worker with pid: 63057
# [2024-08-05 00:42:00 +0000] [63085] [INFO] Booting worker with pid: 63085
# [2024-08-05 00:42:00 +0000] [63131] [INFO] Booting worker with pid: 63131
# [2024-08-05 00:42:00 +0000] [63159] [INFO] Booting worker with pid: 63159
# ^C
# [2024-08-05 00:51:45 +0000] [63054] [INFO] Handling signal: int
# [2024-08-05 00:51:45 +0000] [63085] [INFO] Worker exiting (pid: 63085)
# [2024-08-05 00:51:45 +0000] [63057] [INFO] Worker exiting (pid: 63057)
# [2024-08-05 00:51:45 +0000] [63131] [INFO] Worker exiting (pid: 63131)
# [2024-08-05 00:51:45 +0000] [63159] [INFO] Worker exiting (pid: 63159)

# %%
#mlflow.end_run()

# %%
#cd /Users/macbookpro/Desktop/MLOPS_Project
# Out:
# /Users/macbookpro/Desktop/MLOPS_Project

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ff26a1443a3b> in <cell line: 33>()
#      31 from sklearn.preprocessing import LabelBinarizer
#      32
# ---> 33 from src.make_dataset import *
#      34 from src.make_model import *
#
# ModuleNotFoundError: No module named 'src'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # Cellules à executer pour charger les données

# %% [markdown]
# ## Settings

# %%
# Set logging format
log_fmt = "<green>{time:YYYY-MM-DD HH:mm:ss.SSS!UTC}</green> | <level>{level: <8}</level> | <cyan>{name}</cyan>:<cyan>{function}</cyan>:<cyan>{line}</cyan> - {message}"
logger.configure(handlers=[{"sink": sys.stderr, "format": log_fmt}])

# current data
CURRENT_DATE = pendulum.now(tz="UTC")

# directories
PROJECT_DIR = Path.cwd().parent
REPORTS_DIR = Path(PROJECT_DIR, "reports")

logger.info(f"\nProject directory: {PROJECT_DIR} \nReports dir: {REPORTS_DIR}")
# Out:
# 2024-08-05 15:37:14.886 | INFO     | __main__:<cell line: 12>:12 -
# Project directory: /content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps
# Reports dir: /content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/reports

# %% [markdown]
# ## Load Data

# %%
pwd
# Out:
# '/content/drive/MyDrive/Cours/Informatique/Dic3/Cours/MLOPS/Projet_MLOps/MLOPS_Project'

# %%
#base_dir = '/Users/macbookpro/Desktop/Garbage classification/archive/Garbage classification/Garbage_classification'
base_dir = 'Garbage_classification'

# %%
imgs_data,labels_data, class_names = load_data(base_dir)
# Out:
# ...
# Loading glass: 100%|██████████| 501/501 [00:04<00:00, 115.07it/s]

# %%
class_names
# Out:
# ['paper', 'metal', 'cardboard', 'plastic', 'trash', 'glass']

# %% [markdown]
# ## Vizualisation & Preprocessing

# %%
visualize_class_distribution(labels_data, class_names)

# %%
plot_images_from_subfolders(base_dir)
# Out:
# Images de: paper
# Images de: metal
# Images de: cardboard
# Images de: plastic
# Images de: trash
# Images de: glass

# %%
img_dimensions(base_dir)
# Out:
# Analyse des images en: Garbage_classification/paper
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (384, 512), Fréquence: 594
#
#
# Analyse des images en: Garbage_classification/metal
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (384, 512), Fréquence: 410
#
#
# Analyse des images en: Garbage_classification/cardboard
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (384, 512), Fréquence: 403
#
#
# Analyse des images en: Garbage_classification/plastic
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (384, 512), Fréquence: 482
#
#
# Analyse des images en: Garbage_classification/trash
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (384, 512), Fréquence: 137
#
#
# Analyse des images en: Garbage_classification/glass
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (384, 512), Fréquence: 501

# %%
#processed_dir = "/Users/macbookpro/Desktop/Garbage classification/archive/Garbage classification/processed_images"
processed_dir = "/processed_images"
data, labels = process_dataset(base_dir, processed_dir)
# Out:
# Classe cardboard : 403 processed
# Classe glass : 501 processed
# Classe metal : 410 processed
# Classe paper : 594 processed
# Classe plastic : 482 processed
# Classe trash : 137 processed

# %%
img_dimensions(processed_dir)
# Out:
# Analyse des images en: /processed_images/cardboard
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (128, 128), Fréquence: 403
#
#
# Analyse des images en: /processed_images/paper
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (128, 128), Fréquence: 594
#
#
# Analyse des images en: /processed_images/plastic
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (128, 128), Fréquence: 482
#
#
# Analyse des images en: /processed_images/trash
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (128, 128), Fréquence: 137
#
#
# Analyse des images en: /processed_images/glass
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (128, 128), Fréquence: 501
#
#
# Analyse des images en: /processed_images/metal
# Dimensions les plus courantes:
# Dimension (hauteur x largeur): (128, 128), Fréquence: 410

# %%
plot_images_from_subfolders(processed_dir)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Normalization & Encoding

# %%
# Convertit la liste data en un tableau NumPy.
# Spécifie le type de données comme "float32" pour la précision et l'efficacité
# Divise toutes les valeurs par 255.0, normalisant ainsi les pixels dans la plage [0, 1]
data = np.array(data, dtype="float32") / 255.0
#Convertit la liste labels en un tableau NumPy pour un traitement ultérieur efficace.
labels = np.array(labels)
# Crée une instance de LabelBinarizer de scikit-learn qui va encoder les étiquettes textuelles en format numérique
mlb = LabelBinarizer()
labels = mlb.fit_transform(labels)
#Affiche la première étiquette encodée pour vérification.
print(labels[0])
# Out:
# [1 0 0 0 0 0]

# %% [markdown]
# ## Apply augmentation to the dataset

# %%
final_imgs_data, final_labels_data = increase_dataset(data, labels)

# %%
print("Size before augmentation : ",data.shape[0])
print("Size After augmentation : ",final_imgs_data.shape[0])
# Out:
# Size before augmentation :  2527
# Size After augmentation :  5054

# %% [markdown]
# ## Split Data

# %%
x_train, x_val, x_test, y_train, y_val, y_test = split_data(final_imgs_data, final_labels_data)
# Out:
# Ensemble d'entraînement : (3650, 128, 128, 3), Ensemble de validation : (645, 128, 128, 3), Ensemble de test : (759, 128, 128, 3)

# %%
# Utilisation de la fonction
classes = np.arange(labels.shape[1])

# Vérifiez les distributions des classes dans chaque ensemble
train_class_distribution = check_class_distribution(y_train, classes)
val_class_distribution = check_class_distribution(y_val, classes)
test_class_distribution = check_class_distribution(y_test, classes)

print("Distribution des classes dans l'ensemble d'entraînement :", train_class_distribution)
print("Distribution des classes dans l'ensemble de validation :", val_class_distribution)
print("Distribution des classes dans l'ensemble de test :", test_class_distribution)
# Out:
# Distribution des classes dans l'ensemble d'entraînement : {0: 580, 1: 706, 2: 596, 3: 870, 4: 699, 5: 199}
# Distribution des classes dans l'ensemble de validation : {0: 95, 1: 131, 2: 94, 3: 159, 4: 132, 5: 34}
# Distribution des classes dans l'ensemble de test : {0: 131, 1: 165, 2: 130, 3: 159, 4: 133, 5: 41}
