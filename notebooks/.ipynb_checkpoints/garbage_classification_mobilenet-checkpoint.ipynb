# %%
# %reload_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

import cv2
import os
import numpy as np
from collections import Counter
from tqdm import tqdm
import random
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from sklearn.utils import shuffle
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import save_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img

# %%
sys.path.append(str(Path.cwd().parent))
from src.make_dataset import load_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 sys.path.append(str(Path.cwd().parent))
# ----> 2 from src.make_dataset import load_data
#
# ModuleNotFoundError: No module named 'src.make_dataset'

# %%
for path in sys.path:
    print(path)
# Out:
# /Users/macbookpro/Desktop/MLOPS_Project/notebooks
# /Users/macbookpro/miniforge3/envs/tf2/lib/python38.zip
# /Users/macbookpro/miniforge3/envs/tf2/lib/python3.8
# /Users/macbookpro/miniforge3/envs/tf2/lib/python3.8/lib-dynload
#
# /Users/macbookpro/miniforge3/envs/tf2/lib/python3.8/site-packages
# /Users/macbookpro/miniforge3/envs/tf2/lib/python3.8/site-packages/certifi-2023.11.17-py3.8.egg
# /Users/macbookpro/Desktop/MLOPS_Project
# /Users/macbookpro/Desktop/MLOPS_Project
# /Users/macbookpro/Desktop/MLOPS_Project
# /Users/macbookpro/Desktop/MLOPS_Project

# %%
# Out:
# /Users/macbookpro/Desktop/MLOPS_Project/notebooks

# %%
labels:dict={"cardboard":0,"glass":2,"metal":3,"paper":1,"plastic":5,"trash":4}
SIZE:tuple=(128,128) # MobileNetV2 typically expects images of size 224x224 pixels

# %% [markdown]
# # Load DATA

# %%
def load_data(path: str, size: tuple = (150, 150)) -> tuple:
    images = []
    labels = []
    class_names = []
    labels_ = {}  # Dictionnaire pour mapper les noms de classe aux étiquettes numériques
    current_label = 0
    
    for class_name in os.listdir(path):
        class_path = os.path.join(path, class_name)
        if os.path.isdir(class_path):
            if class_name not in labels_:
                labels_[class_name] = current_label
                class_names.append(class_name)
                current_label += 1
            for img_name in tqdm(os.listdir(class_path), desc=f"Loading {class_name}"):
                img_path = os.path.join(class_path, img_name)
                img = cv2.imread(img_path)
                if img is not None:
                    img = cv2.resize(img, size)  # Resize images to 150x150
                    images.append(img)
                    labels.append(labels_[class_name])
    
    images = np.array(images)
    labels = np.array(labels)
    return images, labels, class_names

# %%
imgs_data,labels_data, class_names = load_data("/Users/macbookpro/Desktop/Garbage classification/archive/Garbage classification/Garbage_classification",SIZE)
# Out:
# Loading paper: 100%|█████████████████████████| 594/594 [00:00<00:00, 999.71it/s]
# Loading metal: 100%|█████████████████████████| 410/410 [00:00<00:00, 933.36it/s]
# Loading cardboard: 100%|█████████████████████| 403/403 [00:00<00:00, 845.98it/s]
# Loading trash: 100%|█████████████████████████| 137/137 [00:00<00:00, 732.03it/s]
# Loading glass: 100%|█████████████████████████| 501/501 [00:00<00:00, 639.20it/s]
# Loading plastic: 100%|███████████████████████| 482/482 [00:00<00:00, 687.35it/s]

# %% [markdown]
# ## Visualization

# %%
def visualize_class_distribution(labels: np.ndarray, class_names: list):
    class_counts = Counter(labels)
    plt.figure(figsize=(10, 6))
    plt.bar(class_counts.keys(), class_counts.values(), tick_label=class_names)
    plt.xlabel('Classes')
    plt.ylabel('Counts')
    plt.title('Distribution des classes')
    plt.show()

# %%
visualize_class_distribution(labels, class_names)

# %% [markdown]
# # Apply augmentation to the dataset

# %%
# Define the image data generator with augmentation
datagen = ImageDataGenerator(
    rotation_range=20,         # Randomly rotate images in the range 0-20 degrees
    width_shift_range=0.2,     # Randomly shift images horizontally by 20% of the width
    height_shift_range=0.2,    # Randomly shift images vertically by 20% of the height
    shear_range=0.2,           # Randomly shear images
    zoom_range=0.2,            # Randomly zoom into images
    horizontal_flip=True,      # Randomly flip images horizontally
    fill_mode='nearest'        # Fill in newly created pixels after rotation or shift
)

# Augment the dataset
augmented_images = []
augmented_labels = []

augmentation_count = int(len(imgs_data) * (1/3))

for img, label in zip(imgs_data, labels_data):
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    i = 0
    for batch in datagen.flow(img, batch_size=1):
        augmented_images.append(batch[0].astype('uint8'))
        augmented_labels.append(label)
        i += 1
        if i >= (augmentation_count / len(imgs_data)):
            break

# Convert lists to numpy arrays
augmented_images = np.array(augmented_images)
augmented_labels = np.array(augmented_labels)

# Combine the original and augmented data
final_imgs_data = np.concatenate((imgs_data, augmented_images), axis=0)
final_labels_data = np.concatenate((labels_data, augmented_labels), axis=0)

# %%
print("Size before augmentation : ",imgs_data.shape[0])
print("Size After augmentation : ",final_imgs_data.shape[0])
# Out:
# Size before augmentation :  2527
# Size After augmentation :  5054

# %% [markdown]
# # Display images

# %%
def show_random_images(images: np.ndarray, labels: np.ndarray, num_samples: int, mode: str = 'BGR2RGB'):
    if num_samples > len(images):
        raise ValueError("Number of samples requested exceeds available samples.")
    
    # Randomly select indices
    random_indices = random.sample(range(len(images)), num_samples)
    
    class_names={j:i for i,j in labels_.items()}
    
    selected_images = images[random_indices]
    selected_labels = [class_names[labels[index]].capitalize() for index in random_indices]

    # Define the number of rows and columns for displaying images
    num_cols = 3
    num_rows = (num_samples + num_cols - 1) // num_cols

    plt.figure(figsize=(15, 5 * num_rows))

    for i, (img, label) in enumerate(zip(selected_images, selected_labels)):
        plt.subplot(num_rows, num_cols, i + 1)
        if isinstance(mode,str) and not mode is None:
            mode=mode.upper()
        if mode == 'GRAY':
            img_display = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            plt.imshow(img_display, cmap='gray')
        elif mode == 'BGR2RGB':
            img_display = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            plt.imshow(img_display)
        elif mode == 'RGB':
            plt.imshow(img)
        else:
            raise ValueError(f"Unsupported mode: {mode}")
        plt.title(label)
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
def display_image(images: np.ndarray, labels: np.ndarray, index: int, mode: str = 'RGB'):
    if index >= len(images):
        raise ValueError("Index is out of range for images array.")
    
    # Mapping of class indices to class names (assuming labels are numeric)
    class_names={j:i for i,j in labels_.items()}  # Replace with your actual class names or logic
    
    img = images[index]
    label = class_names[labels[index]]

    plt.figure(figsize=(5, 5))
    
    if isinstance(mode, str) and mode.upper() == 'GRAY':
        img_display = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        plt.imshow(img_display, cmap='gray')
    elif isinstance(mode, str) and mode.upper() == 'BGR2RGB':
        img_display = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.imshow(img_display)
    elif isinstance(mode, str) and mode.upper() == 'RGB':
        plt.imshow(img)
    else:
        raise ValueError(f"Unsupported mode: {mode}")
    
    plt.title(label.capitalize())
    plt.axis('off')
    plt.show()

# %% [markdown]
# # Split the data

# %%
# Split data into training+validation (80%) and test (20%)
X_train, X_test, y_train, y_test = train_test_split(final_imgs_data, final_labels_data, test_size=0.2, random_state=42)

# %%
# Convert labels to one-hot encoding
num_classes = len(np.unique(labels_data))
num_classes
# Out:
# 6

# %% [markdown]
# ## Display the train data

# %%
show_random_images(X_train, y_train,9)

# %% [markdown]
# ## Display the test data

# %%
show_random_images(X_test, y_test,9)

# %% [markdown]
# # Transfer Learning with MobileNetV2

# %% [markdown]
# ## Normalize Data

# %%
# Normalize your image data
X_train = np.array(X_train) / 255.0
X_test = np.array(X_test) / 255.0
y_train = np.array(y_train)
y_test = np.array(y_test)

# %% [markdown]
# ## Define the MobileNetV2 model

# %%
base_model = MobileNetV2(input_shape=(128, 128, 3), include_top=False, weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 [==============================] - 9s 1us/step

# %% [markdown]
# ## Freeze the base model

# %%
base_model.trainable = False

# %% [markdown]
# ## Create a new model on top

# %%
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(512, activation='relu'),    
    Dense(num_classes, activation='softmax')  # assuming classification task
])

# %% [markdown]
# ## Compile the model

# %%
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss=SparseCategoricalCrossentropy(),
              metrics=[SparseCategoricalAccuracy()])

# %% [markdown]
# ## Define early stopping callback

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=1, restore_best_weights=True)

# %% [markdown]
# ## Train the model

# %%
# Train the model with early stopping
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 102/102 [==============================] - 60s 562ms/step - loss: 1.0941 - sparse_categorical_accuracy: 0.5925 - val_loss: 0.8205 - val_sparse_categorical_accuracy: 0.7046
# Epoch 2/50
# 102/102 [==============================] - 53s 517ms/step - loss: 0.6328 - sparse_categorical_accuracy: 0.7814 - val_loss: 0.6950 - val_sparse_categorical_accuracy: 0.7454
# Epoch 3/50
# 102/102 [==============================] - 40s 392ms/step - loss: 0.4796 - sparse_categorical_accuracy: 0.8485 - val_loss: 0.6421 - val_sparse_categorical_accuracy: 0.7689
# Epoch 4/50
# 102/102 [==============================] - 35s 342ms/step - loss: 0.3913 - sparse_categorical_accuracy: 0.8840 - val_loss: 0.6056 - val_sparse_categorical_accuracy: 0.7800
# Epoch 5/50
# 102/102 [==============================] - 37s 364ms/step - loss: 0.3270 - sparse_categorical_accuracy: 0.9066 - val_loss: 0.5918 - val_sparse_categorical_accuracy: 0.7886
# Epoch 6/50
# 102/102 [==============================] - 36s 357ms/step - loss: 0.2670 - sparse_categorical_accuracy: 0.9351 - val_loss: 0.5728 - val_sparse_categorical_accuracy: 0.7911
# Epoch 7/50
# 102/102 [==============================] - 48s 471ms/step - loss: 0.2283 - sparse_categorical_accuracy: 0.9456 - val_loss: 0.5540 - val_sparse_categorical_accuracy: 0.8035
# Epoch 8/50
# 102/102 [==============================] - 42s 410ms/step - loss: 0.1893 - sparse_categorical_accuracy: 0.9626 - val_loss: 0.5424 - val_sparse_categorical_accuracy: 0.8133
# Epoch 9/50
# 102/102 [==============================] - 45s 441ms/step - loss: 0.1611 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.5304 - val_sparse_categorical_accuracy: 0.8084
# Epoch 10/50
# 102/102 [==============================] - 41s 403ms/step - loss: 0.1373 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.5234 - val_sparse_categorical_accuracy: 0.8183
# Epoch 11/50
# 102/102 [==============================] - 44s 429ms/step - loss: 0.1172 - sparse_categorical_accuracy: 0.9873 - val_loss: 0.5229 - val_sparse_categorical_accuracy: 0.8183
# Epoch 12/50
# 102/102 [==============================] - 42s 418ms/step - loss: 0.1013 - sparse_categorical_accuracy: 0.9917 - val_loss: 0.5084 - val_sparse_categorical_accuracy: 0.8208
# Epoch 13/50
# 102/102 [==============================] - 47s 460ms/step - loss: 0.0876 - sparse_categorical_accuracy: 0.9954 - val_loss: 0.5075 - val_sparse_categorical_accuracy: 0.8121
# Epoch 14/50
# 102/102 [==============================] - 48s 469ms/step - loss: 0.0772 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.5044 - val_sparse_categorical_accuracy: 0.8220
# Epoch 15/50
# 102/102 [==============================] - 53s 523ms/step - loss: 0.0685 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.5020 - val_sparse_categorical_accuracy: 0.8171
# Epoch 16/50
# 102/102 [==============================] - 38s 373ms/step - loss: 0.0625 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.4955 - val_sparse_categorical_accuracy: 0.8319
# Epoch 17/50
# 102/102 [==============================] - 39s 386ms/step - loss: 0.0518 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.4935 - val_sparse_categorical_accuracy: 0.8282
# Epoch 18/50
# 102/102 [==============================] - 51s 505ms/step - loss: 0.0459 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.4952 - val_sparse_categorical_accuracy: 0.8269

# %% [markdown]
# ## Evaluate the model

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_acc}")
# Out:
# 32/32 [==============================] - 9s 274ms/step - loss: 0.4257 - sparse_categorical_accuracy: 0.8556
# Test accuracy: 0.8555885553359985

# %%
# Extracting history from training
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['sparse_categorical_accuracy']
val_acc = history.history['val_sparse_categorical_accuracy']

# Plotting the training and validation loss
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plotting the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Test

# %%
# Make predictions
index_test = 136
# Assuming X_train[0] is the first image in your training data
image_to_predict = np.expand_dims(X_test[index_test], axis=0)  # Add batch dimension if necessary

# Make predictions
predictions = model.predict(image_to_predict)
predicted_class = np.argmax(predictions[0])
classes = {value:key for key,value in labels_.items()}
# Print predicted class
print(f"Predicted class: {classes[predicted_class]},\t Real class: {classes[y_test[index_test]]}")
display_image(X_test,y_test,index_test)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# Predicted class: cardboard,	 Real class: cardboard
